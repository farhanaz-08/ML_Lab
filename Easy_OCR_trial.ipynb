# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanaz-08/ML_Lab/blob/main/Easy_OCR_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install easyocr
# !pip install Pillow

# %%
from google.colab import files

uploaded = files.upload()   # Upload ANY image you want
image_path = list(uploaded.keys())[0]

print("Uploaded:", image_path)
# Out:
#      <input type="file" id="files-8fe08d5c-7fca-43ac-896f-5ebadc39c42e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fe08d5c-7fca-43ac-896f-5ebadc39c42e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1279.5), np.float64(719.5), np.float64(-0.5))

# %%
import easyocr

# Load OCR reader (Bangla + English)
reader = easyocr.Reader(['bn', 'en'])

# Extract text
result = reader.readtext(image_path, detail=0)

print("\n========== Extracted Text ==========\n")
for line in result:
    print(line)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ========== Extracted Text ==========
#
# Brc
# [$
# VICE PREC
# AFTER
# Breaking News
# TRUMP A
# VICE PRESIDENT STEPS IN AFTER
# ATION
# TRUMP ALLY'S ASSASSINATION
# Story:
# The Vice President witl officially replace
# Story:
# Charlie Kirk as host of his popular show
# Kirk, a close ally of Donald Trump
# Was
# shot dead in a shocking attack last
# The Vice Pre
# Week
# replace
# The takeover aims to keep the
# program's conservative influence alive
# Chartie Kirk
# Meanwhile, authorities continue an
# shoW.
# intense manhunt for the suspected
# shooter
# Kirk, a close
# How do you feel about this nEWs?
# rump, was
# ৬0গ1tn৮t`৮০শ t
# ...
